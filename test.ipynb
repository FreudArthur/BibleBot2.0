# %%
import main_freud
import bible_vector
import os
# Out:
# WARNING:tensorflow:From e:\cours ifri\Programmation et BD\Python\env_py\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print(main_freud.ask("Qui est Noé dans la bible"))
# Out:
# Bonjour ! 😊 C'est une excellente question.
#
# **Noé**, ou **Noé** comme il est appelé dans la Bible (généralement écrit **Noé(h)** en français selon les translations), est une figure centrale de l’Ancien Testament pour son rôle dans l’histoire du déluge.
#
# Il est présenté comme un homme juste (ce qui signifie "intègre, moralement solide"), fidèle et qui marchait avec Dieu dans le monde profondément corrompu de *son époque*. Son histoire nous est racontée dans **Genèse 6 à 9** : une époque marquée par les violences et l’immoralité, où tout homme avait *"la pensée de son cœur fixée seulement sur le mal"*, à tel point que Dieu regretta d’avoir créé la humanité (Genèse 6.5).
#
# Pourtant, Noé fut trouvé *grave* (c’est-à-dire favorablement et en plein accord avec sa volonté div) :
# > **« Noé était homme juste et intègre entre ses contemporains ; Noé marchait avec Dieu. ») — Genèse 6.9**
#
# ...

# %%
os.path.isfile("OpenBible.fr-FR.pdf")
# Out:
# True
